# %% [markdown]
# ![MLOps Abstract PPT - AI-based frame interpolation for WMS_Page_1.jpg](<attachment:MLOps Abstract PPT - AI-based frame interpolation for WMS_Page_1.jpg>)

# %% [markdown]
# ![MLOps Abstract PPT - AI-based frame interpolation for WMS_Page_2.jpg](<attachment:MLOps Abstract PPT - AI-based frame interpolation for WMS_Page_2.jpg>)

# %% [markdown]
# ![MLOps Abstract PPT - AI-based frame interpolation for WMS_Page_3.jpg](<attachment:MLOps Abstract PPT - AI-based frame interpolation for WMS_Page_3.jpg>)

# %% [markdown]
# ![MLOps Abstract PPT - AI-based frame interpolation for WMS_Page_4.jpg](<attachment:MLOps Abstract PPT - AI-based frame interpolation for WMS_Page_4.jpg>)

# %% [markdown]
# ![MLOps Abstract PPT - AI-based frame interpolation for WMS_Page_5.jpg](<attachment:MLOps Abstract PPT - AI-based frame interpolation for WMS_Page_5.jpg>)
